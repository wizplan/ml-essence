# %%
a = 4
b = 5
a * b
# Out:
# 20

# %%
# %run -i ex2_01.py
# Out:
# 15

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5)
y = x**2
plt.plot(x, y)
plt.show()
